# %% [markdown]
# # Device code credentials example
#
# This notebook shows how to use the Timeseries API with device code credentials

# %% [markdown]
# Import the required libraries. The `azure.identity` package will handle the actual authentication to the API

# %%
from omnia_timeseries.api import TimeseriesAPI, TimeseriesEnvironment
from azure.identity import DeviceCodeCredential
import os

# %% [markdown]
# Set up the API with the desired environment

# %%
credentials = DeviceCodeCredential(client_id=os.environ["AZURE_CLIENT_ID"], tenant_id=os.environ["AZURE_TENANT_ID"])
api = TimeseriesAPI(azure_credential=credentials, environment=TimeseriesEnvironment.Beta())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-0ce9416ac2b1> in <module>
# ----> 1 credentials = DeviceCodeCredential(client_id=os.environ["AZURE_CLIENT_ID"], tenant_id=os.environ["AZURE_TENANT_ID"])
#       2 api = TimeseriesAPI(azure_credential=credentials, environment=TimeseriesEnvironment.Beta())
#
# NameError: name 'os' is not defined

# %% [markdown]
# Invoking the API with device code credentials will display a code and a url to enter in a browser window. After this is completed, the execution will proceed.

# %%
api.get_latest_datapoint(id="91f945d3-be34-4f8c-a43f-e00a3a2d9cfc")
# Out:
# To sign in, use a web browser to open the page https://microsoft.com/devicelogin and enter the code DHB746Z6K to authenticate.
# Json {'Authorization': 'Bearer eyJ0eXAiOiJKV1QiLCJhbGciOiJSUzI1NiIsIng1dCI6Im5PbzNaRHJPRFhFSzFqS1doWHNsSFJfS1hFZyIsImtpZCI6Im5PbzNaRHJPRFhFSzFqS1doWHNsSFJfS1hFZyJ9.....SZaYoEgpPAUhRA6c1UlGUVjMtlvFA-TKihSg_OMvW4u6Kn_u2Fmm42G8h5mZgYsLbH0BZs5F-pPS1I_lOy2e2SEwzNOGM9rxBah_N1eGfASb8XvJYHqVFGG27RSGSC6GGZTQsGzNXktkGskWfPi245X1cUKhJPUL3mp_xNjtCtYZfMZBRjlmzdQo4VGIrybjZaXNqhAOrZQZpEmITPHFt6ZsKHb0RvD1xjFLxyZtlVPQo_Uod-HH17rE5zIBa5mK-rDc12BN6pDRnAVF47lZu6aapjKCEEBQqS5MvoEmUYccTxz3d-R0LOSYwbMs_H5061Fg8SeBrR-cua9YvPFJ7g', 'Accept': 'application/json', 'User-Agent': 'Omnia Timeseries SDK/1.0.2 (Windows; Python 10.0.19043)'}
# {'data': {'items': [{'id': '91f945d3-be34-4f8c-a43f-e00a3a2d9cfc',
#     'datapoints': []}]}}
